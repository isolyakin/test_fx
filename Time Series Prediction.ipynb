# %% [markdown]
# https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/

# %%
import pandas
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = 10, 8

# %%
dataset = pandas.read_csv('international-airline-passengers.csv', usecols=[1], engine='python', skipfooter=3)
plt.plot(dataset)
plt.show()

# %% [markdown]
# ## LSTM Network for Regression

# %%
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# fix random seed for reproducibility
numpy.random.seed(7)# load the dataset

dataframe = pandas.read_csv('international-airline-passengers.csv', usecols=[1], engine='python', skipfooter=3)
dataset = dataframe.values
dataset = dataset.astype('float32')
dataframe.head()
# Out:
#    International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# 0                                                112
# 1                                                118
# 2                                                132
# 3                                                129
# 4                                                121

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 96 48

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
trainX[:10]
# Out:
# array([[0.01544401],
#        [0.02702703],
#        [0.05405405],
#        [0.04826255],
#        [0.03281853],
#        [0.05984557],
#        [0.08494207],
#        [0.08494207],
#        [0.06177607],
#        [0.02895753]], dtype=float32)

# %%
trainY[:10]
# Out:
# array([0.02702703, 0.05405405, 0.04826255, 0.03281853, 0.05984557,
#        0.08494207, 0.08494207, 0.06177607, 0.02895753, 0.        ],
#       dtype=float32)

# %%
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
trainX.shape
# Out:
# (94, 1, 1)

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
history = model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=1)
# Out:
# Epoch 1/100
# 94/94 [==============================] - 202s 2s/step - loss: 0.0414
# Epoch 2/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0202
# Epoch 3/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0145
# Epoch 4/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0131
# Epoch 5/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0121
# Epoch 6/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0111
# Epoch 7/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0102
# Epoch 8/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0093
# Epoch 9/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0081
# Epoch 10/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0071
# Epoch 11/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0062
# Epoch 12/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0053
# Epoch 13/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0045
# Epoch 14/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0038
# Epoch 15/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0033
# Epoch 16/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0029
# Epoch 17/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0026
# Epoch 18/100
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0024
# Epoch 19/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0022
# Epoch 20/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0022
# Epoch 21/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 22/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0021
# Epoch 23/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0021
# Epoch 24/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0021
# Epoch 25/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 26/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0021
# Epoch 27/100
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0020
# Epoch 28/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 29/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 30/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 31/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 32/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 33/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 34/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0021
# Epoch 35/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0021
# Epoch 36/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 37/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 38/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 39/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0021
# Epoch 40/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0020
# Epoch 41/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 42/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 43/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0021
# Epoch 44/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0020
# Epoch 45/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0021
# Epoch 46/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0020
# Epoch 47/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0020
# Epoch 48/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 49/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0020
# Epoch 50/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 51/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 52/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0020
# Epoch 53/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 54/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 55/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 56/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0020
# Epoch 57/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0020
# Epoch 58/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 59/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0020
# Epoch 60/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 61/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 62/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 63/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 64/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 65/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 66/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 67/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 68/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 69/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0020
# Epoch 70/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 71/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 72/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 73/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 74/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0021
# Epoch 75/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0021
# Epoch 76/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 77/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0021
# Epoch 78/100
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0019
# Epoch 79/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0022
# Epoch 80/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 81/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 82/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 83/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 84/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 85/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0021
# Epoch 86/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0021
# Epoch 87/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 88/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 89/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 90/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 91/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 92/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 93/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0021
# Epoch 94/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0021
# Epoch 95/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 96/100
#  - ETA: 0s - loss: 0.0016
# Epoch 97/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 98/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 99/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 100/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0020

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss'])

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 22.93 RMSE
# Test Score: 47.53 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# ## LSTM for Regression Using the Window Method

# %%
# LSTM for international airline passengers problem with window regression framing
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# fix random seed for reproducibility
numpy.random.seed(7)
# load the dataset
dataframe = read_csv('international-airline-passengers.csv', usecols=[1], engine='python', skipfooter=3)
dataset = dataframe.values
dataset = dataset.astype('float32')

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
trainX.shape
# Out:
# (92, 1, 3)

# %%
trainX[:10,:,:]
# Out:
# array([[[0.01544401, 0.02702703, 0.05405405]],
#
#        [[0.02702703, 0.05405405, 0.04826255]],
#
#        [[0.05405405, 0.04826255, 0.03281853]],
#
#        [[0.04826255, 0.03281853, 0.05984557]],
#
#        [[0.03281853, 0.05984557, 0.08494207]],
#
#        [[0.05984557, 0.08494207, 0.08494207]],
#
#        [[0.08494207, 0.08494207, 0.06177607]],
#
#        [[0.08494207, 0.06177607, 0.02895753]],
#
#        [[0.06177607, 0.02895753, 0.        ]],
#
#        [[0.02895753, 0.        , 0.02702703]]], dtype=float32)

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
history = model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=1)
# Out:
# Epoch 1/100
# 92/92 [==============================] - 2s 23ms/step - loss: 0.0544
# Epoch 2/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0259
# Epoch 3/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0167
# Epoch 4/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0145
# Epoch 5/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0129
# Epoch 6/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0117
# Epoch 7/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0105
# Epoch 8/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0094
# Epoch 9/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0081
# Epoch 10/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0074
# Epoch 11/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0066
# Epoch 12/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0060
# Epoch 13/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0056
# Epoch 14/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0052
# Epoch 15/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0050
# Epoch 16/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0049
# Epoch 17/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0046
# Epoch 18/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0045
# Epoch 19/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0045
# Epoch 20/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0043
# Epoch 21/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0043
# Epoch 22/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0042
# Epoch 23/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0042
# Epoch 24/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0042
# Epoch 25/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0040
# Epoch 26/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0041
# Epoch 27/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0040
# Epoch 28/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0040
# Epoch 29/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0039
# Epoch 30/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0038
# Epoch 31/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0038
# Epoch 32/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0037
# Epoch 33/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0037
# Epoch 34/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0037
# Epoch 35/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0036
# Epoch 36/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0035
# Epoch 37/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0036
# Epoch 38/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0035
# Epoch 39/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0035
# Epoch 40/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0034
# Epoch 41/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0035
# Epoch 42/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0034
# Epoch 43/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0033
# Epoch 44/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0033
# Epoch 45/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0032
# Epoch 46/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0034
# Epoch 47/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0031
# Epoch 48/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0031
# Epoch 49/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0031
# Epoch 50/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0030
# Epoch 51/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0030
# Epoch 52/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0029
# Epoch 53/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0030
# Epoch 54/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0028
# Epoch 55/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0028
# Epoch 56/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0028
# Epoch 57/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0027
# Epoch 58/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0028
# Epoch 59/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0027
# Epoch 60/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0028
# Epoch 61/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0027
# Epoch 62/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0026
# Epoch 63/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0025
# Epoch 64/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0028
# Epoch 65/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0025
# Epoch 66/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0025
# Epoch 67/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0024
# Epoch 68/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0025
# Epoch 69/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0024
# Epoch 70/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0024
# Epoch 71/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0024
# Epoch 72/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0024
# Epoch 73/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0024
# Epoch 74/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0023
# Epoch 75/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0023
# Epoch 76/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0023
# Epoch 77/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0024
# Epoch 78/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0023
# Epoch 79/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0023
# Epoch 80/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0023
# Epoch 81/100
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0023
# Epoch 82/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0022
# Epoch 83/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0022
# Epoch 84/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0022
# Epoch 85/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0022
# Epoch 86/100
# 92/92 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 87/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0023
# Epoch 88/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 89/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 90/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 91/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 92/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 93/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 94/100
# 92/92 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 95/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0021
# Epoch 96/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0021
# Epoch 97/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0021
# Epoch 98/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0021
# Epoch 99/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0022
# Epoch 100/100
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0020

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Train Score: 24.19 RMSE
# Test Score: 58.04 RMSE

# %% [markdown]
# ## LSTM for Regression with Time Steps

# %%
# LSTM for international airline passengers problem with time step regression framing
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# fix random seed for reproducibility
numpy.random.seed(7)
# load the dataset
dataframe = read_csv('international-airline-passengers.csv', usecols=[1], engine='python', skipfooter=3)
dataset = dataframe.values
dataset = dataset.astype('float32')

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
trainX.shape
# Out:
# (92, 3)

# %%
trainX[:5,:]
# Out:
# array([[0.01544401, 0.02702703, 0.05405405],
#        [0.02702703, 0.05405405, 0.04826255],
#        [0.05405405, 0.04826255, 0.03281853],
#        [0.04826255, 0.03281853, 0.05984557],
#        [0.03281853, 0.05984557, 0.08494207]], dtype=float32)

# %%
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = numpy.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %%
trainX.shape
# Out:
# (92, 3, 1)

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
history = model.fit(trainX, trainY, epochs=20, batch_size=10, verbose=1)
# Out:
# Epoch 1/20
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0509
# Epoch 2/20
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0420
# Epoch 3/20
# 92/92 [==============================] - 0s 2ms/step - loss: 0.0343
# Epoch 4/20
# 92/92 [==============================] - 0s 1ms/step - loss: 0.0281
# Epoch 5/20
# 92/92 [==============================] - 0s 1ms/step - loss: 0.0227
# Epoch 6/20
# 92/92 [==============================] - 0s 1ms/step - loss: 0.0185
# Epoch 7/20
# 92/92 [==============================] - 0s 1ms/step - loss: 0.0157
# Epoch 8/20
# 92/92 [==============================] - 0s 1ms/step - loss: 0.0134
# Epoch 9/20
# 92/92 [==============================] - 0s 1ms/step - loss: 0.0117
# Epoch 10/20
# 92/92 [==============================] - 0s 1ms/step - loss: 0.0110
# Epoch 11/20
# 92/92 [==============================] - 0s 1ms/step - loss: 0.0103
# Epoch 12/20
# 92/92 [==============================] - 0s 1ms/step - loss: 0.0100
# Epoch 13/20
# 92/92 [==============================] - 0s 1ms/step - loss: 0.0098
# Epoch 14/20
# 92/92 [==============================] - 0s 1ms/step - loss: 0.0095
# Epoch 15/20
# 92/92 [==============================] - 0s 994us/step - loss: 0.0093
# Epoch 16/20
# 92/92 [==============================] - 0s 1ms/step - loss: 0.0091
# Epoch 17/20
# 92/92 [==============================] - 0s 1ms/step - loss: 0.0089
# Epoch 18/20
# 92/92 [==============================] - 0s 1ms/step - loss: 0.0087
# Epoch 19/20
# 92/92 [==============================] - 0s 1ms/step - loss: 0.0085
# Epoch 20/20
# 92/92 [==============================] - 0s 973us/step - loss: 0.0083

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Train Score: 46.95 RMSE
# Test Score: 136.22 RMSE

# %%
import keras
keras.__version__
# Out:
# '2.1.5'
